# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data = pd.read_csv("C:\\Users\\Shudhir Singh\\Downloads\\drugs_side_effects_drugs_com.csv")
df= data.head(20)
data_framed=df.fillna("unknown")
print(data_framed)
data2=data_framed.isnull().sum()
print(data2)
# Out:
#            drug_name medical_condition  \
# 0        doxycycline              Acne
# 1     spironolactone              Acne
# 2        minocycline              Acne
# 3           Accutane              Acne
# 4        clindamycin              Acne
# 5          Aldactone              Acne
# 6          tretinoin              Acne
# 7       isotretinoin              Acne
# 8            Bactrim              Acne
# 9            Retin-A              Acne
# 10            Aczone              Acne
# 11  benzoyl peroxide              Acne
# 12          Differin              Acne
# 13            Epiduo              Acne
# 14         adapalene              Acne
# 15        cephalexin              Acne
# 16             Doryx              Acne
# 17      tetracycline              Acne
# 18            Septra              Acne
# 19           Solodyn              Acne
#
#                                          side_effects  \
# 0   (hives, difficult breathing, swelling in your ...
# ...

# %%
data2.describe()
plt.figure(figsize=(10, 6))
sns.histplot(data= data["rating"], bins=10, kde= "true" )
plt.title("Distribution of Drug Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency ")
side_effects2= df["side_effects"].value_counts().head(10)
print(side_effects2)
# Out:
# side_effects
# ...

# %%
data = pd.read_csv("C:\\Users\\Shudhir Singh\\Downloads\\drugs_side_effects_drugs_com.csv")
df= pd.DataFrame(data)
print(df.columns)
# Out:
# Index(['drug_name', 'medical_condition', 'side_effects', 'generic_name',
#        'drug_classes', 'brand_names', 'activity', 'rx_otc',
#        'pregnancy_category', 'csa', 'alcohol', 'related_drugs',
#        'medical_condition_description', 'rating', 'no_of_reviews', 'drug_link',
#        'medical_condition_url'],
#       dtype='object')

# %%
top_drugs =df.groupby('medical_condition')['drug_name'].value_counts().nlargest(10)
print(top_drugs)
plt.figure(figsize=(10,8))
sns.boxplot(data=df, x="drug_classes", y="rating")
plt.xticks(rotation=90)
plt.title("Drugs Rating by Class")
plt.ylabel("Rating")
# Out:
# medical_condition  drug_name
# Acne               minocycline       2
# Eczema             fluocinolone      2
# Herpes             acyclovir         2
# ADHD               Adderall          1
#                    Adderall XR       1
#                    Adhansia XR       1
#                    Adzenys ER        1
#                    Adzenys XR-ODT    1
#                    Aptensio XR       1
#                    Azstarys          1
# Name: count, dtype: int64
# Text(0, 0.5, 'Rating')

# %%
print('The dataset has {} rows and {} columns'.format(df.shape[0], df.shape[1]))
print("columns Names are as follows:")

print(df.columns)
data_framed.info()
# Out:
# The dataset has 2931 rows and 17 columns
# columns Names are as follows:
# Index(['drug_name', 'medical_condition', 'side_effects', 'generic_name',
#        'drug_classes', 'brand_names', 'activity', 'rx_otc',
#        'pregnancy_category', 'csa', 'alcohol', 'related_drugs',
#        'medical_condition_description', 'rating', 'no_of_reviews', 'drug_link',
#        'medical_condition_url'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   drug_name                      20 non-null     object
#  1   medical_condition              20 non-null     object
#  2   side_effects                   20 non-null     object
#  3   generic_name                   20 non-null     object
#  4   drug_classes                   20 non-null     object
# ...

# %%
print(data_framed.head())
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
data_duplicated= df.duplicated()
print(data_duplicated)
duplicated_count= data_duplicated.shape[0]
print("duplicated count values is :",duplicated_count)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2926    False
# 2927    False
# 2928    False
# 2929    False
# 2930    False
# Length: 2931, dtype: bool
# duplicated count values is : 2931

# %%
df["rating"]= pd.to_numeric(df["rating"], errors="coerce")
print(df["rating"])
# Out:
# 0       6.8
# 1       7.2
# 2       5.7
# 3       7.9
# 4       7.4
#        ...
# 2926    7.5
# 2927    NaN
# 2928    NaN
# 2929    NaN
# 2930    NaN
# Name: rating, Length: 2931, dtype: float64

# %%
df['activity'] =df['activity'].astype(str).str.replace(r'\s+', '',regex=True).str.rstrip('%').astype('float')/100
print(df['activity'])
# Out:
# 0       0.87
# 1       0.82
# 2       0.48
# 3       0.41
# 4       0.39
#         ...
# 2926    0.02
# 2927    0.01
# 2928    0.00
# 2929    0.00
# 2930    0.00
# Name: activity, Length: 2931, dtype: float64

# %%
print("There are {} missing values in this dataset".format(data.isnull().sum().sum()))
print('Number of instances = %d' %(data.shape[0]))
print('Number of instances= %d' %(data.shape[1]))
print('Number of missing values')
for col in data.columns:
    print('%s:%d ' %(col,data[col].isna().sum()))
# Out:
# There are 7405 missing values in this dataset
# Number of instances = 2931
# Number of instances= 17
# Number of missing values
# drug_name:0
# medical_condition:0
# side_effects:124
# generic_name:43
# drug_classes:82
# brand_names:1213
# activity:0
# rx_otc:1
# pregnancy_category:229
# csa:0
# alcohol:1554
# related_drugs:1469
# medical_condition_description:0
# rating:1345
# no_of_reviews:1345
# drug_link:0
# medical_condition_url:0

# %%
data["alcohol"]= data["alcohol"].replace([np.nan,0],0)
data["alcohol"]= data["alcohol"].replace({'X':1,'x':1,'unknown':2})
print(data["alcohol"])
data['no_of_reviews']=data['no_of_reviews'].replace(np.nan, 0)
print(data['no_of_reviews'])
data['rating']=data['rating'].replace(np.nan, 0)
print(data['rating'])
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 2926    1
# 2927    1
# 2928    1
# 2929    0
# 2930    0
# Name: alcohol, Length: 2931, dtype: int64
# 0       760.0
# 1       449.0
# 2       482.0
# 3       623.0
# 4       146.0
#         ...
# 2926     17.0
# 2927      0.0
# 2928      0.0
# 2929      0.0
# 2930      0.0
# Name: no_of_reviews, Length: 2931, dtype: float64
# 0       6.8
# 1       7.2
# 2       5.7
# 3       7.9
# 4       7.4
#        ...
# 2926    7.5
# 2927    0.0
# 2928    0.0
# 2929    0.0
# 2930    0.0
# Name: rating, Length: 2931, dtype: float64
# C:\Users\Shudhir Singh\AppData\Local\Temp\ipykernel_6304\1506655296.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['side_effects']=data['side_effects'].replace(np.nan,"unknown")
data['related_drugs']= data['related_drugs'].replace(np.nan,'unknown')
data['no_of_reviews']= data['no_of_reviews'].replace(np.nan,'unknown')
print(data['side_effects'])
print(data['related_drugs'])
print(data['no_of_reviews'])
# Out:
# 0       (hives, difficult breathing, swelling in your ...
# 1       hives ; difficulty breathing; swelling of your...
# 2       skin rash, fever, swollen glands, flu-like sym...
# 3       problems with your vision or hearing; muscle o...
# 4       hives ; difficult breathing; swelling of your ...
#                               ...
# 2926    hives ; difficulty breathing; swelling of your...
# 2927    hives ; difficult breathing; swelling of your ...
# 2928                                              unknown
# 2929    Imcivree may cause serious side effects, inclu...
# 2930    hives ; difficult breathing; swelling of your ...
# Name: side_effects, Length: 2931, dtype: object
# 0       amoxicillin: https://www.drugs.com/amoxicillin...
# 1       amlodipine: https://www.drugs.com/amlodipine.h...
# 2       amoxicillin: https://www.drugs.com/amoxicillin...
# 3       doxycycline: https://www.drugs.com/doxycycline...
# 4       doxycycline: https://www.drugs.com/doxycycline...
# ...

# %%
data['generic_name']=data['generic_name'].replace(np.nan,"unknown")
print("data of genric medicine",data['generic_name'])
# Out:
# data of genric medicine 0                    doxycycline
# 1                 spironolactone
# 2                    minocycline
# 3            isotretinoin (oral)
# 4            clindamycin topical
#                   ...
# 2926               benzphetamine
# 2927                fenfluramine
# 2928    phendimetrazine tartrate
# 2929               setmelanotide
# 2930               setmelanotide
# Name: generic_name, Length: 2931, dtype: object

# %%
data['drug_classe']=data['drug_classes'].replace(np.nan,"unknown")
print("data of drug classss",data['drug_classes'])
# Out:
# data of drug classss 0              Miscellaneous antimalarials, Tetracyclines
# 1       Aldosterone receptor antagonists, Potassium-sp...
# 2                                           Tetracyclines
# 3       Miscellaneous antineoplastics, Miscellaneous u...
# 4            Topical acne agents, Vaginal anti-infectives
#                               ...
# 2926                          Anorexiants, CNS stimulants
# 2927    Anorexiants, CNS stimulants, Miscellaneous ant...
# 2928                          Anorexiants, CNS stimulants
# 2929                       Melanocortin receptor agonists
# 2930                       Melanocortin receptor agonists
# Name: drug_classes, Length: 2931, dtype: object

# %%
data["rx_otc"].unique()
# Out:
# array(['Rx', 'Rx/OTC', 'OTC', nan], dtype=object)

# %%
data['pregnancy_category'].unique()
# Out:
# array(['D', 'C', 'X', 'B', 'N', nan, 'A'], dtype=object)

# %%
data['pregnancy_category']=data['pregnancy_category'].replace(np.nan, "unknown")
print(data['pregnancy_category'])
# Out:
# 0             D
# 1             C
# 2             D
# 3             X
# 4             B
#          ...
# 2926          X
# 2927          C
# 2928          C
# 2929    unknown
# 2930    unknown
# Name: pregnancy_category, Length: 2931, dtype: object

# %%
data['rx_otc']=data['rx_otc'].replace(np.nan,'unknown')
print(data['rx_otc'])
# Out:
# 0       Rx
# 1       Rx
# 2       Rx
# 3       Rx
# 4       Rx
#         ..
# 2926    Rx
# 2927    Rx
# 2928    Rx
# 2929    Rx
# 2930    Rx
# Name: rx_otc, Length: 2931, dtype: object

# %%
data['no_of_reviews']= pd.to_numeric(data['no_of_reviews'], errors='coerce')
print(data['no_of_reviews'])
print(data.head())
# Out:
# 0       760.0
# 1       449.0
# 2       482.0
# 3       623.0
# 4       146.0
#         ...
# 2926     17.0
# 2927      0.0
# 2928      0.0
# 2929      0.0
# 2930      0.0
# Name: no_of_reviews, Length: 2931, dtype: float64
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# ...

# %%
print("missing values is {} in the dataset".format(data.isnull().sum().sum()))
print('number of instances ' , data.shape[0])
print('number of instances ' , data.shape[1])
print('number of missing values')
for col in data.columns:
    print(col, data[col].isna().sum())
# Out:
# missing values is 1295 in the dataset
# number of instances  2931
# number of instances  18
# number of missing values
# drug_name 0
# medical_condition 0
# side_effects 0
# generic_name 0
# drug_classes 82
# brand_names 1213
# activity 0
# rx_otc 0
# pregnancy_category 0
# csa 0
# alcohol 0
# related_drugs 0
# medical_condition_description 0
# rating 0
# no_of_reviews 0
# drug_link 0
# medical_condition_url 0
# drug_classe 0

# %%
data_version2 = data.copy()
print(data_version2.head())
# Out:
#         drug_name medical_condition  \
# 0     doxycycline              Acne
# 1  spironolactone              Acne
# 2     minocycline              Acne
# 3        Accutane              Acne
# 4     clindamycin              Acne
#
#                                         side_effects         generic_name  \
# 0  (hives, difficult breathing, swelling in your ...          doxycycline
# 1  hives ; difficulty breathing; swelling of your...       spironolactone
# 2  skin rash, fever, swollen glands, flu-like sym...          minocycline
# 3  problems with your vision or hearing; muscle o...  isotretinoin (oral)
# 4  hives ; difficult breathing; swelling of your ...  clindamycin topical
#
#                                         drug_classes  \
# 0         Miscellaneous antimalarials, Tetracyclines
# 1  Aldosterone receptor antagonists, Potassium-sp...
# 2                                      Tetracyclines
# 3  Miscellaneous antineoplastics, Miscellaneous u...
# ...

# %%
data_version2.to_csv('drugs_medicine_analysis.csv')

# %%
data_ver3= pd.read_csv('drugs_medicine_analysis.csv')
print(data_ver3)
# Out:
#       Unnamed: 0       drug_name medical_condition  \
# 0              0     doxycycline              Acne
# 1              1  spironolactone              Acne
# 2              2     minocycline              Acne
# 3              3        Accutane              Acne
# 4              4     clindamycin              Acne
# ...          ...             ...               ...
# 2926        2926   benzphetamine       Weight Loss
# 2927        2927    fenfluramine       Weight Loss
# 2928        2928     Fendique ER       Weight Loss
# 2929        2929        Imcivree       Weight Loss
# 2930        2930   setmelanotide       Weight Loss
#
#                                            side_effects  \
# 0     (hives, difficult breathing, swelling in your ...
# 1     hives ; difficulty breathing; swelling of your...
# 2     skin rash, fever, swollen glands, flu-like sym...
# 3     problems with your vision or hearing; muscle o...
# 4     hives ; difficult breathing; swelling of your ...
# ...

# %%
data_ver3['pregnancy_category'].unique()
# Out:
# array(['D', 'C', 'X', 'B', 'N', 'unknown', 'A'], dtype=object)

# %%
data_ver3['csa'].unique
# Out:
# <bound method Series.unique of 0       N
# 1       N
# 2       N
# 3       N
# 4       N
#        ..
# 2926    3
# 2927    4
# 2928    3
# 2929    N
# 2930    N
# Name: csa, Length: 2931, dtype: object>

# %%
data_ver3['rx_otc'].unique
# Out:
# <bound method Series.unique of 0       Rx
# 1       Rx
# 2       Rx
# 3       Rx
# 4       Rx
#         ..
# 2926    Rx
# 2927    Rx
# 2928    Rx
# 2929    Rx
# 2930    Rx
# Name: rx_otc, Length: 2931, dtype: object>

# %%
data_ver3['generic_name'].unique
# Out:
# <bound method Series.unique of 0                    doxycycline
# 1                 spironolactone
# 2                    minocycline
# 3            isotretinoin (oral)
# 4            clindamycin topical
#                   ...
# 2926               benzphetamine
# 2927                fenfluramine
# 2928    phendimetrazine tartrate
# 2929               setmelanotide
# 2930               setmelanotide
# Name: generic_name, Length: 2931, dtype: object>

# %%
data_ver3['medical_condition'].unique
# Out:
# <bound method Series.unique of 0              Acne
# 1              Acne
# 2              Acne
# 3              Acne
# 4              Acne
#            ...
# 2926    Weight Loss
# 2927    Weight Loss
# 2928    Weight Loss
# 2929    Weight Loss
# 2930    Weight Loss
# Name: medical_condition, Length: 2931, dtype: object>

# %%
from sklearn.preprocessing import LabelEncoder
load_encoder= LabelEncoder()
data_ver3['csa']= load_encoder.fit_transform(data_ver3['csa'])
data_ver3['rx_otc']= load_encoder.fit_transform(data_ver3['rx_otc'])
data_ver3['generic_name']= load_encoder.fit_transform(data_ver3['generic_name'])
data_ver3['medical_condition']= load_encoder.fit_transform(data_ver3['medical_condition'])
data_ver3['pregnancy_category']= load_encoder.fit_transform(data_ver3['pregnancy_category'])
data_ver3['side_effects']= load_encoder.fit_transform(data_ver3['side_effects'])

# %%
data_ver3['csa'].unique
# Out:
# <bound method Series.unique of 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 2926    1
# 2927    2
# 2928    1
# 2929    5
# 2930    5
# Name: csa, Length: 2931, dtype: int64>

# %%
data_ver3['rx_otc'].unique
# Out:
# <bound method Series.unique of 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2926    1
# 2927    1
# 2928    1
# 2929    1
# 2930    1
# Name: rx_otc, Length: 2931, dtype: int64>

# %%
data_ver3['generic_name'].unique
# Out:
# <bound method Series.unique of 0        641
# 1       1269
# 2       1033
# 3        902
# 4        504
#         ...
# 2926     360
# 2927     728
# 2928    1156
# 2929    1258
# 2930    1258
# Name: generic_name, Length: 2931, dtype: int64>

# %%
data_ver3['medical_condition'].unique
# Out:
# <bound method Series.unique of 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 2926    46
# 2927    46
# 2928    46
# 2929    46
# 2930    46
# Name: medical_condition, Length: 2931, dtype: int64>

# %%
data_ver3['pregnancy_category'].unique
# Out:
# <bound method Series.unique of 0       3
# 1       2
# 2       3
# 3       5
# 4       1
#        ..
# 2926    5
# 2927    2
# 2928    2
# 2929    6
# 2930    6
# Name: pregnancy_category, Length: 2931, dtype: int64>

# %%
data_ver3['side_effects'].unique
# Out:
# <bound method Series.unique of 0         15
# 1       1971
# 2       2696
# 3       2569
# 4       1259
#         ...
# 2926    1954
# 2927    1646
# 2928    2748
# 2929     416
# 2930    1705
# Name: side_effects, Length: 2931, dtype: int64>

# %%
dfg=pd.DataFrame(data_ver3, columns=('generic_name',
'medical_condition', 'no_of_reviews', 'side_effects', 'rating',
'csa', 'pregnancy_category', 'rx_otc', 'alcohol'))
print(dfg)
# Out:
#       generic_name  medical_condition  no_of_reviews  side_effects  rating  \
# 0              641                  2          760.0            15     6.8
# 1             1269                  2          449.0          1971     7.2
# 2             1033                  2          482.0          2696     5.7
# 3              902                  2          623.0          2569     7.9
# 4              504                  2          146.0          1259     7.4
# ...            ...                ...            ...           ...     ...
# 2926           360                 46           17.0          1954     7.5
# 2927           728                 46            0.0          1646     0.0
# 2928          1156                 46            0.0          2748     0.0
# 2929          1258                 46            0.0           416     0.0
# 2930          1258                 46            0.0          1705     0.0
#
#       csa  pregnancy_category  rx_otc  alcohol
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(dfg)
scaled_data=scaler.transform(dfg)
print(scaled_data)
# Out:
# [[-0.15452517 -1.43400434  5.10119829 ...  0.25170355 -0.17025661
#    1.06232778]
#  [ 1.44420187 -1.43400434  2.89586941 ... -0.43584828 -0.17025661
#    1.06232778]
#  [ 0.84340636 -1.43400434  3.12987537 ...  0.25170355 -0.17025661
#   -0.94132905]
#  ...
#  [ 1.15653284  1.82918864 -0.28802985 ... -0.43584828 -0.17025661
#    1.06232778]
#  [ 1.41619869  1.82918864 -0.28802985 ...  2.31435905 -0.17025661
#   -0.94132905]
#  [ 1.41619869  1.82918864 -0.28802985 ...  2.31435905 -0.17025661
#   -0.94132905]]

# %%
df_std = pd.DataFrame(scaler.fit_transform(dfg),columns=dfg.columns)
print(df_std)
# Out:
#       generic_name  medical_condition  no_of_reviews  side_effects    rating  \
# 0        -0.154525          -1.434004       5.101198     -1.735325  0.819930
# 1         1.444202          -1.434004       2.895869      0.638350  0.925271
# 2         0.843406          -1.434004       3.129875      1.518162  0.530244
# 3         0.509914          -1.434004       4.129719      1.364043  1.109617
# 4        -0.503292          -1.434004       0.747269     -0.225687  0.977941
# ...            ...                ...            ...           ...       ...
# 2926     -0.869879           1.829189      -0.167481      0.617719  1.004277
# 2927      0.066955           1.829189      -0.288030      0.243951 -0.970861
# 2928      1.156533           1.829189      -0.288030      1.581266 -0.970861
# 2929      1.416199           1.829189      -0.288030     -1.248697 -0.970861
# 2930      1.416199           1.829189      -0.288030      0.315549 -0.970861
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(dfg.corr(),annot=True,cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_ver4=pd.read_csv('drugs_medicine_analysis.csv')
from mlxtend.frequent_patterns import apriori
import matplotlib.pyplot as plt
import pandas as pd
medical_condition_counts =data_ver4['medical_condition'].value_counts().sort_values(ascending=False)
print(medical_condition_counts)
# Out:
# medical_condition
# Pain                    264
# Colds & Flu             245
# Acne                    238
# Hypertension            177
# Osteoarthritis          129
# Hayfever                124
# Eczema                  122
# AIDS/HIV                109
# Diabetes (Type 2)       104
# Psoriasis                93
# GERD (Heartburn)         77
# Pneumonia                72
# Bronchitis               71
# Angina                   71
# Migraine                 61
# Insomnia                 60
# Constipation             60
# Diabetes (Type 1)        57
# Osteoporosis             56
# ADHD                     55
# Depression               51
# Seizures                 50
# Bipolar Disorder         47
# UTI                      46
# Asthma                   45
# Cholesterol              45
# Anxiety                  45
# Diarrhea                 38
# Covid 19                 34
# Rheumatoid Arthritis     33
# Alzheimer's              27
# COPD                     23
# ...

# %%
medical_condition_counts.to_csv("medical_condition_counts.csv")

# %%
from collections import Counter 
import re
def extract_side_effects(text):
    return [effect.strip() for effect in re.split(r'[;]', text)]

# Assuming 'data_ver4' is your DataFrame and it has a column named 'side_effects'
side_effects = data_ver4['side_effects'].dropna().apply(extract_side_effects).explode()

side_effects_counts = side_effects.value_counts().sort_values(ascending=False)

print(side_effects_counts)
# Out:
# side_effects
# hives                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1788
# ...

# %%
side_effects_counts.to_csv('side_effects_counts.csv')

# %%
def extract_drug_classes(text):
    return [effect.strip() for effect in re.split(r'[,]', text)]
drug_classes =data_ver4['drug_classes'].dropna().apply(extract_drug_classes).explode()
drug_classes_counts = drug_classes.value_counts().sort_values(ascending=False)
print("\nDrug Classes occurrence and frequency (sorted from highest to lowest):")
print(drug_classes_counts)
# Out:
# Drug Classes occurrence and frequency (sorted from highest to lowest):
# drug_classes
# Upper respiratory combinations          245
# Topical acne agents                     125
# Topical steroids                         94
# Antihistamines                           82
# Nonsteroidal anti-inflammatory drugs     72
#                                        ...
# Antipseudomonal penicillins               1
# CD52 monoclonal antibodies                1
# Progestins                                1
# Interferons                               1
# Thioxanthenes                             1
# Name: count, Length: 243, dtype: int64

# %%
drug_classes_counts.to_csv('drug_classes_counts.csv')

# %%
def has_hives(text):
 return 'hives' in text.lower()
data_ver4['hives']= data_ver4['side_effects'].apply(has_hives)
print(data_ver4['hives'])
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2926     True
# 2927     True
# 2928    False
# 2929    False
# 2930     True
# Name: hives, Length: 2931, dtype: bool

# %%
def has_breathing(text):
 return 'breathing' in text.lower() or 'difficulty_in_breathing' in text.lower()
data_ver4['breathing']= data_ver4['side_effects'].apply(has_breathing)

# %%
def has_itching(text):
    return 'itching' in text.lower()
data_ver4['itching']= data_ver4['side_effects'].apply(has_itching)

# %%
def is_usc(text):
    if isinstance(text, str):
       return 'Upper respiratory combinations' in text
       return false
data_ver4['upper respiratory_combinations']= data_ver4['drug_classes'].apply(is_usc)
print(data_ver4
      ['upper respiratory_combinations'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2926    False
# 2927    False
# 2928    False
# 2929    False
# 2930    False
# Name: upper respiratory_combinations, Length: 2931, dtype: object

# %%
def is_steroids(text):
    if isinstance(text, str):
     return 'steroids' in text
    return False

data_ver4['steroids']= data_ver4['drug_classes'].apply(is_steroids)
print(data_ver4['steroids'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2926    False
# 2927    False
# 2928    False
# 2929    False
# 2930    False
# Name: steroids, Length: 2931, dtype: bool

# %%
def is_acne(text):
    if isinstance(text, str):
      return'topical_acne_aggents' in text
    return False
data_ver4['topical_acne_aggents']= data_ver4['drug_classes'].apply(is_acne)

# %%
def has_pain(text):
 return 'pain' in text
data_ver4['has_pain']=data_ver4['medical_condition'].apply(has_pain)

# %%
def has_cold_and_flu(text):
    return 'cold and flu' in text
data_ver4['cold_and_flu']= data['medical_condition'].apply(has_cold_and_flu)

# %%
def has_acne(text):
    return 'acne' in text
data_ver4['acne']= data['medical_condition'].apply(has_acne)

# %%
import seaborn as sns
sns.barplot(data= data_ver4['hives'].value_counts())
plt.xlabel('Hives')
plt.ylabel('Counts')
plt.title('Counts of Hives')
plt.xticks( rotation=0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data=data_ver4['breathing'].value_counts())
plt.xlabel('Breathing')
plt.ylabel('Count')
plt.title('Count of difficult breathing')
plt.xticks(rotation=0)
# Out:
# ([0, 1], [Text(0, 0, 'False'), Text(1, 0, 'True')])

# %%
sns.barplot(data=data_ver4['itching'].value_counts())
# Out:
# <Axes: xlabel='itching', ylabel='count'>

# %%
sns.barplot(data=data_ver4['upper respiratory_combinations'] .value_counts())
plt.xlabel("Upper Respiratory Combinations")
plt.title("Counts of Respiratory Problems")
# Out:
# Text(0.5, 1.0, 'Counts of Respiratory Problems')

# %%
sns.barplot(data=data_ver4['steroids'].value_counts())
plt.xticks([0,1],['False','True'], rotation = 90)
# Out:
# ([<matplotlib.axis.XTick at 0x1e4f34ed310>,
# ...
#  [Text(0, 0, 'False'), Text(1, 0, 'True')])

# %%
data['pregnancy_category']= data_ver4['pregnancy_category'].replace('unknown','Not pregnant')
data['pregnancy_category'].value_counts().plot.pie(autopct='%1.1f%%', textprops={'fontsize':12}).set_title("Target distribution on pregnancy_category")
data['pregnancy_category'].value_counts()
# Out:
# pregnancy_category
# C               1382
# B                509
# N                436
# Not pregnant     229
# D                228
# X                129
# A                 18
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,15))
data_ver4['medical_condition'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(10,15))
sns.pairplot(data=data_ver4[["medical_condition", "rating", "no_of_reviews"]], kind='scatter', hue='medical_condition')
